# %% [markdown]
# # DATA SCIENCE INTERN @BHARAT INTERN

# %% [markdown]
# ### NAME : ABHINANDAN KUMAR

# %% [markdown]
# # TASK 1 : STOCK PREDICTION

# %% [markdown]
# ## PURPOSE : TO PREDICT THE STOCK PRICE OF A COMPANY USING LSTM.

# %% [markdown]
# ## ABOUT DATASET
# ### Google Stock Prediction
#
# This dataset contains historical data of **Google's stock prices** and related attributes. It consists of 14 columns and a smaller subset of 1257 rows. Each column represents a specific attribute, and each row contains the corresponding values for that attribute.
#
# The columns in the dataset are as follows:
#
# 1. **Symbol**: The name of the company, which is **GOOG** in this case.
# 2. **Date**: The year and date of the stock data.
# 3. **Close**: The closing price of Google's stock on a particular day.
# 4. **High**: The highest value reached by Google's stock on the given day.
# 5. **Low**: The lowest value reached by Google's stock on the given day.
# 6. **Open**: The opening value of Google's stock on the given day.
# 7. **Volume**: The trading volume of Google's stock on the given day, i.e., the number of shares traded.
# 8. **adjClose**: The adjusted closing price of Google's stock, considering factors such as dividends and stock splits.
# 9. **adjHigh**: The adjusted highest value reached by Google's stock on the given day.
# 10. **adjLow**: The adjusted lowest value reached by Google's stock on the given day.
# 11. **adjOpen**: The adjusted opening value of Google's stock on the given day.
# 12. **adjVolume**: The adjusted trading volume of Google's stock on the given day, accounting for factors such as stock splits.
# 13. **divCash**: The amount of cash dividend paid out to shareholders on the given day.
# 14. **splitFactor**: The split factor, if any, applied to Google's stock on the given day. A split factor of 1 indicates no split.
#
# The dataset is available at Kaggle : https://www.kaggle.com/datasets/shreenidhihipparagi/google-stock-prediction

# %% [markdown]
# ## STEPS INVOLVED :
# ### 1 . IMPORTING LIBRARIES AND DATA TO BE USED
# ### 2. GATHERING INSIGHTS
# ### 3. DATA PRE-PROCESSING
# ### 4. CREATING LSTM MODEL
# ### 5. VISUALIZING ACTUAL VS PREDICTED DATA
# ### 6. PREDICTING UPCOMING 15 DAYS

# %% [markdown]
# ## STEP 1 : IMPORTING LIBRARIES AND DATA TO BE USED

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv("C:\\Users\\HP\\Downloads\\Task_1_Stocks_dataset.csv") # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# ## STEP 2 : GATHERING INSIGHTS

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# ### There are no null values in the dataset

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# ## STEP 3 : DATA PRE-PROCESSING

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# ## STEP 4 :  CREATING LSTM MODEL

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 7s 65ms/step - loss: 0.0073 - mean_absolute_error: 0.0604 - val_loss: 0.0201 - val_mean_absolute_error: 0.1132
# Epoch 2/100
# 28/28 [==============================] - 1s 34ms/step - loss: 8.4703e-04 - mean_absolute_error: 0.0229 - val_loss: 0.0084 - val_mean_absolute_error: 0.0681
# Epoch 3/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.6507e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0060 - val_mean_absolute_error: 0.0597
# Epoch 4/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.4225e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0072 - val_mean_absolute_error: 0.0659
# Epoch 5/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.3316e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0068 - val_mean_absolute_error: 0.0646
# Epoch 6/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.5981e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0067 - val_mean_absolute_error: 0.0643
# Epoch 7/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.1083e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0059 - val_mean_absolute_error: 0.0594
# Epoch 8/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.9300e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0055 - val_mean_absolute_error: 0.0568
# Epoch 9/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.0315e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0057 - val_mean_absolute_error: 0.0595
# Epoch 10/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.6918e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0064 - val_mean_absolute_error: 0.0635
# Epoch 11/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.7163e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0064 - val_mean_absolute_error: 0.0639
# Epoch 12/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.4695e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0046 - val_mean_absolute_error: 0.0528
# Epoch 13/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.4218e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0043 - val_mean_absolute_error: 0.0507
# Epoch 14/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.3815e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0045 - val_mean_absolute_error: 0.0523
# Epoch 15/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.2537e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0067 - val_mean_absolute_error: 0.0671
# Epoch 16/100
# 28/28 [==============================] - 3s 93ms/step - loss: 3.2475e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0026 - val_mean_absolute_error: 0.0378
# Epoch 17/100
# 28/28 [==============================] - 3s 100ms/step - loss: 3.0146e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0065 - val_mean_absolute_error: 0.0660
# Epoch 18/100
# 28/28 [==============================] - 5s 176ms/step - loss: 3.2833e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0061 - val_mean_absolute_error: 0.0633
# Epoch 19/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.8826e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0046 - val_mean_absolute_error: 0.0537
# Epoch 20/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.8375e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0046 - val_mean_absolute_error: 0.0535
# Epoch 21/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.6688e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0068 - val_mean_absolute_error: 0.0682
# Epoch 22/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.9713e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0065 - val_mean_absolute_error: 0.0663
# Epoch 23/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.7494e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0043 - val_mean_absolute_error: 0.0530
# Epoch 24/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.8487e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0043 - val_mean_absolute_error: 0.0527
# Epoch 25/100
# 28/28 [==============================] - 1s 37ms/step - loss: 2.7110e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0032 - val_mean_absolute_error: 0.0442
# Epoch 26/100
# 28/28 [==============================] - 1s 35ms/step - loss: 2.5143e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0029 - val_mean_absolute_error: 0.0424
# Epoch 27/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.4142e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0028 - val_mean_absolute_error: 0.0416
# Epoch 28/100
# 28/28 [==============================] - 1s 37ms/step - loss: 2.6634e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0023 - val_mean_absolute_error: 0.0361
# Epoch 29/100
# 28/28 [==============================] - 1s 42ms/step - loss: 2.7245e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0018 - val_mean_absolute_error: 0.0312
# Epoch 30/100
# 28/28 [==============================] - 1s 43ms/step - loss: 2.4353e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0052 - val_mean_absolute_error: 0.0585
# Epoch 31/100
# 28/28 [==============================] - 1s 42ms/step - loss: 2.5516e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0069 - val_mean_absolute_error: 0.0697
# Epoch 32/100
# 28/28 [==============================] - 1s 43ms/step - loss: 2.5192e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0033 - val_mean_absolute_error: 0.0455
# Epoch 33/100
# 28/28 [==============================] - 1s 42ms/step - loss: 2.4381e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0016 - val_mean_absolute_error: 0.0299
# Epoch 34/100
# 28/28 [==============================] - 1s 41ms/step - loss: 2.2054e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0034 - val_mean_absolute_error: 0.0466
# Epoch 35/100
# 28/28 [==============================] - 1s 42ms/step - loss: 2.1736e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0014 - val_mean_absolute_error: 0.0281
# Epoch 36/100
# 28/28 [==============================] - 1s 41ms/step - loss: 2.1369e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0024 - val_mean_absolute_error: 0.0380
# Epoch 37/100
# 28/28 [==============================] - 1s 41ms/step - loss: 2.1872e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0029 - val_mean_absolute_error: 0.0417
# Epoch 38/100
# 28/28 [==============================] - 1s 41ms/step - loss: 2.2384e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0023 - val_mean_absolute_error: 0.0367
# Epoch 39/100
# 28/28 [==============================] - 1s 41ms/step - loss: 2.0027e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0046 - val_mean_absolute_error: 0.0558
# Epoch 40/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.9778e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0026 - val_mean_absolute_error: 0.0402
# Epoch 41/100
# 28/28 [==============================] - 1s 41ms/step - loss: 2.0462e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0028 - val_mean_absolute_error: 0.0412
# Epoch 42/100
# 28/28 [==============================] - 1s 43ms/step - loss: 1.9962e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0032 - val_mean_absolute_error: 0.0447
# Epoch 43/100
# 28/28 [==============================] - 1s 41ms/step - loss: 2.1379e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0035 - val_mean_absolute_error: 0.0469
# Epoch 44/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.8604e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0041 - val_mean_absolute_error: 0.0513
# Epoch 45/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.8978e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0055 - val_mean_absolute_error: 0.0606
# Epoch 46/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.7766e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0027 - val_mean_absolute_error: 0.0387
# Epoch 47/100
# 28/28 [==============================] - 1s 41ms/step - loss: 2.0529e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0021 - val_mean_absolute_error: 0.0347
# Epoch 48/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.8002e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0015 - val_mean_absolute_error: 0.0290
# Epoch 49/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.8157e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0021 - val_mean_absolute_error: 0.0337
# Epoch 50/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.6480e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0036 - val_mean_absolute_error: 0.0478
# Epoch 51/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.8631e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
# Epoch 52/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.8870e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0026 - val_mean_absolute_error: 0.0384
# Epoch 53/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.6997e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0025 - val_mean_absolute_error: 0.0389
# Epoch 54/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.5915e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0024 - val_mean_absolute_error: 0.0370
# Epoch 55/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.6787e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0045 - val_mean_absolute_error: 0.0533
# Epoch 56/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.5777e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0041 - val_mean_absolute_error: 0.0484
# Epoch 57/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.6199e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0031 - val_mean_absolute_error: 0.0408
# Epoch 58/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.6606e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0044 - val_mean_absolute_error: 0.0542
# Epoch 59/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.8210e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0058 - val_mean_absolute_error: 0.0615
# Epoch 60/100
# 28/28 [==============================] - 1s 40ms/step - loss: 1.4570e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0044 - val_mean_absolute_error: 0.0517
# Epoch 61/100
# 28/28 [==============================] - 1s 40ms/step - loss: 1.6645e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0052 - val_mean_absolute_error: 0.0579
# Epoch 62/100
# 28/28 [==============================] - 1s 40ms/step - loss: 1.5105e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0040 - val_mean_absolute_error: 0.0504
# Epoch 63/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.3807e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0020 - val_mean_absolute_error: 0.0328
# Epoch 64/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.4801e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0031 - val_mean_absolute_error: 0.0412
# Epoch 65/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.4853e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0028 - val_mean_absolute_error: 0.0400
# Epoch 66/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.3109e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0036 - val_mean_absolute_error: 0.0487
# Epoch 67/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.6262e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0052 - val_mean_absolute_error: 0.0594
# Epoch 68/100
# 28/28 [==============================] - 1s 40ms/step - loss: 1.3569e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0031 - val_mean_absolute_error: 0.0434
# Epoch 69/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.4131e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0035 - val_mean_absolute_error: 0.0459
# Epoch 70/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.4298e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0034 - val_mean_absolute_error: 0.0443
# Epoch 71/100
# 28/28 [==============================] - 1s 40ms/step - loss: 1.3807e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0039 - val_mean_absolute_error: 0.0489
# Epoch 72/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.4880e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0032 - val_mean_absolute_error: 0.0445
# Epoch 73/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.3392e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0020 - val_mean_absolute_error: 0.0331
# Epoch 74/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.4559e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0038 - val_mean_absolute_error: 0.0484
# Epoch 75/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.2606e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0030 - val_mean_absolute_error: 0.0420
# Epoch 76/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.2623e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0036 - val_mean_absolute_error: 0.0465
# Epoch 77/100
# 28/28 [==============================] - 1s 40ms/step - loss: 1.3368e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0042 - val_mean_absolute_error: 0.0533
# Epoch 78/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.3722e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0038 - val_mean_absolute_error: 0.0487
# Epoch 79/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.2661e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0046 - val_mean_absolute_error: 0.0548
# Epoch 80/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.2945e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0043 - val_mean_absolute_error: 0.0516
# Epoch 81/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.1249e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0029 - val_mean_absolute_error: 0.0413
# Epoch 82/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.1552e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0032 - val_mean_absolute_error: 0.0430
# Epoch 83/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.3118e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0033 - val_mean_absolute_error: 0.0436
# Epoch 84/100
# 28/28 [==============================] - 1s 44ms/step - loss: 1.1601e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0030 - val_mean_absolute_error: 0.0409
# Epoch 85/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.0783e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0041 - val_mean_absolute_error: 0.0477
# Epoch 86/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.2773e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0027 - val_mean_absolute_error: 0.0402
# Epoch 87/100
# 28/28 [==============================] - 1s 42ms/step - loss: 1.1587e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0036 - val_mean_absolute_error: 0.0450
# Epoch 88/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.3431e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0035 - val_mean_absolute_error: 0.0461
# Epoch 89/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.3244e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0017 - val_mean_absolute_error: 0.0299
# Epoch 90/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.1763e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0018 - val_mean_absolute_error: 0.0303
# Epoch 91/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.2168e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0021 - val_mean_absolute_error: 0.0341
# Epoch 92/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.1368e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0015 - val_mean_absolute_error: 0.0273
# Epoch 93/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.0403e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0022 - val_mean_absolute_error: 0.0341
# Epoch 94/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.2485e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0031 - val_mean_absolute_error: 0.0416
# Epoch 95/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.1246e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0034 - val_mean_absolute_error: 0.0455
# Epoch 96/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.1268e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0023 - val_mean_absolute_error: 0.0360
# Epoch 97/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.1500e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0032 - val_mean_absolute_error: 0.0442
# Epoch 98/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.0209e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0034 - val_mean_absolute_error: 0.0451
# Epoch 99/100
# 28/28 [==============================] - 1s 41ms/step - loss: 9.7889e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0019 - val_mean_absolute_error: 0.0320
# Epoch 100/100
# 28/28 [==============================] - 1s 41ms/step - loss: 1.1872e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0040 - val_mean_absolute_error: 0.0520

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 11ms/step
# array([[0.39153844, 0.39146546],
#        [0.39199868, 0.39176014],
#        [0.38861662, 0.38826594],
#        [0.3924925 , 0.3925777 ],
#        [0.39674056, 0.3969714 ]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1396.881 , 1393.7786],
#        [1397.7341, 1394.3247],
#        [1391.4641, 1387.8488],
#        [1398.6497, 1395.84  ],
#        [1406.5253, 1403.983 ]], dtype=float32)

# %% [markdown]
# ## STEP 5 :  VISUALIZING ACTUAL VS PREDICTED DATA

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1396.880981      1393.778564
# 2020-05-28  1396.86  1416.73     1397.734131      1394.324707
# 2020-05-29  1416.94  1428.92     1391.464111      1387.848755
# 2020-06-01  1418.39  1431.82     1398.649658      1395.839966
# 2020-06-02  1430.55  1439.22     1406.525269      1403.983032

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ## STEP 6. PREDICTING UPCOMING 10 DAYS

# %%
# Creating a dataframe and adding 10 days to existing index 

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2340.048584      2238.266846
# 2021-06-10  2494.01  2521.60     2338.512207      2234.299805
# 2021-06-11  2524.92  2513.93     2356.307129      2252.498047
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
# # THANK YOU!
